# %% [markdown]
# # **Лабораторна робота №1**
# ## **Варіант 1**
# ### Виконав роботу: Білич Андрій
# ---
# Номери реалізацій
# *1, 2, 5, 14, 21, 33, 43, 50, 62, 79, 85, 96*

# %% [markdown]
# Імпортуємо всі потрібні бібліотеки

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
from math import ceil, sqrt

# Для кореляційної матриці
from numpy.linalg import norm as np_norm

# %% [markdown]
# Запишемо реалізації випадкового процесу

# %%
data = {
    1: [-0.588, -0.896, -0.867, 0.075, 0.729, 0.494, 0.771, 0.113, 0.231, 0.400],
    2: [-0.656, 0.410, -0.732, 0.839, 0.093, 0.523, 0.899, -0.194, 0.789, 0.178],
    5: [-0.326, -1.800, -0.690, -0.404, -0.136, -1.157, 0.047, 0.088, -0.061, 0.963],
    14: [0.510, 0.316, -0.908, 0.330, 0.688, -0.217, 0.722, 0.257, -0.032, -0.367],
    21: [-0.486, -0.534, -0.195, -0.169, 0.376, 0.764, 1.340, 0.318, -0.187, 1.020],
    33: [-0.476, -0.419, -0.514, 0.095, 0.292, 1.460, 0.900, -0.201, 0.491, -0.726],
    43: [-0.796, 0.257, -0.243, -0.006, 1.580, 1.700, 1.060, -0.228, 0.460, 0.006],
    50: [-0.526, -0.080, -0.492, -0.235, 0.754, 1.070, 0.861, 0.819, -0.351, 0.102],
    62: [-0.544, -0.736, -0.994, -0.129, 0.694, 0.816, 0.654, 0.404, -0.308, 0.089],
    79: [-0.559, -0.178, -0.759, 0.266, 0.683, 0.106, 0.588, 0.622, 0.107, 0.216],
    85: [-0.505, -0.520, -0.620, 0.043, 0.561, 1.220, 0.700, 1.020, 0.201, -0.136],
    96: [-0.596, -0.164, -0.489, 0.333, 0.055, 0.050, 0.837, 0.743, 0.269, -0.020],
}

df = pd.DataFrame(data)
time_points = df.index  # моменти часу
time_points
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %% [markdown]
# # 2) Знайти оцінки числових характеристик кожного з перерізів випадкового процесу:
# ### а) математичного сподівання

# %%
mean_values = df.mean(axis=1)
# Out:
# 0   -0.462333
# 1   -0.362000
# 2   -0.625250
# 3    0.086500
# 4    0.530750
# 5    0.569083
# 6    0.781583
# 7    0.313417
# 8    0.134083
# 9    0.143750
# dtype: float64

# %% [markdown]
# ### б) дисперсії

# %%
var_values = df.var(axis=1)
# Out:
# 0    0.106287
# 1    0.376553
# 2    0.062527
# 3    0.107714
# 4    0.200819
# 5    0.630475
# 6    0.093656
# 7    0.177478
# 8    0.117710
# 9    0.241560
# dtype: float64

# %% [markdown]
# ### в) середньоквадратичного відхилення

# %%
std_values = df.std(axis=1)

# %% [markdown]
# ### Побудувати графіки залежності математичного сподівання і середньоквадратичного відхилення від часу

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(time_points, mean_values, label="Математичне сподівання", color='blue')
plt.xlabel('Час')
plt.ylabel('Математичне сподівання')
plt.title('Залежність математичного сподівання від часу')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(time_points, std_values, label="Середньоквадратичне відхилення", color='red')
plt.xlabel('Час')
plt.ylabel('Середньоквадратичне відхилення')
plt.title('Залежність середньоквадратичного відхилення від часу')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3) Для кожного перерізу випадкового процесу побудувати гістограму і приблизно оцінити вид розподілу відповідних випадкових величин.
# При побудові гістограми для вибору кількості інтервалів використовувати формулу Стерджеса.

# %%
# Побудова гістограм для кожного перерізу
for col in df.columns:
    plt.figure(figsize=(8, 4))
    plt.hist(df[col], bins=ceil(1 + 3.322 * np.log10(len(df))), color='skyblue', edgecolor='black', density=True)
    sns.kdeplot(df[col], color='red', label='Оцінка розподілу')
    plt.title(f'Гістограма реалізації №{col}')
    plt.xlabel('Значення')
    plt.ylabel('Частота')
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## 4) Для отримання кореляційної матриці випадкового процесу X(t) обчислити кореляційні моменти перерізів процесу X(t) в дискретні моменти часу

# %%
corr_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Кореляційна матриця')
plt.show()

# %% [markdown]
# ## Привести її до нормованого вигляду

# %%
mean_values = df.mean(axis=1)

var_values = df.var(axis=1)

corr_moments = np.zeros((len(df), len(df)))

for i in range(len(df)):
    for j in range(len(df)):
        corr_moments[i, j] = np.sum((df.iloc[i] - mean_values[i]) * (df.iloc[j] - mean_values[j])) / (len(df.columns) - 1)

# Нормування кореляційної матриці
norm_corr_matrix = np.zeros((len(df.columns), len(df.columns)))

for i in range(len(df.columns)):
    for j in range(len(df.columns)):
        norm_corr_matrix[i, j] = corr_matrix.iloc[i, j]

plt.figure(figsize=(10, 8))
sns.heatmap(norm_corr_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Нормована кореляційна матриця')
plt.show()

corr_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Нормована кореляційна матриця')
plt.show()
df_corr == df.corr()
# Out:
#       1     2     5     14    21    33    43    50    62    79    85    96
# 1   True  True  True  True  True  True  True  True  True  True  True  True
# 2   True  True  True  True  True  True  True  True  True  True  True  True
# 5   True  True  True  True  True  True  True  True  True  True  True  True
# 14  True  True  True  True  True  True  True  True  True  True  True  True
# 21  True  True  True  True  True  True  True  True  True  True  True  True
# 33  True  True  True  True  True  True  True  True  True  True  True  True
# 43  True  True  True  True  True  True  True  True  True  True  True  True
# 50  True  True  True  True  True  True  True  True  True  True  True  True
# 62  True  True  True  True  True  True  True  True  True  True  True  True
# 79  True  True  True  True  True  True  True  True  True  True  True  True
# 85  True  True  True  True  True  True  True  True  True  True  True  True
# ...

# %% [markdown]
# ## Графіки 12-ти реалізацій випадкового процесу, математичного сподівання та ±Середньоквадратичного відхилення

# %%
plt.figure(figsize=(12, 6))
for column in df.columns:
    plt.plot(time_points, df[column], label=f'Реалізація {column}', alpha=0.6)

plt.plot(time_points, mean_values, label="Математичне сподівання", color='black', linewidth=4)
plt.fill_between(time_points, mean_values - std_values, mean_values + std_values, color='gray', alpha=0.3, label='±Середньоквадратичне відхилення')

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title('Графіки 12-ти реалізацій випадкового процесу')
plt.xlabel('Час')
plt.ylabel('Значення')
plt.grid(True)
# Встановлення міток осі X
plt.xticks(ticks=np.arange(0, 10, 1))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 plt.figure(figsize=(12, 6))
#       2 for column in df.columns:
#       3     plt.plot(time_points, df[column], label=f'Реалізація {column}', alpha=0.6)
#
# NameError: name 'plt' is not defined

# %%
mean_values = df.mean(axis=1)

var_values = df.var(axis=1)

corr_moments = np.zeros((len(df), len(df)))

for i in range(len(df)):
    for j in range(len(df)):
        corr_moments[i, j] = np.sum((df.iloc[i] - mean_values[i]) * (df.iloc[j] - mean_values[j])) / (len(df.columns) - 1)

norm_corr_matrix = np.zeros((len(df), len(df)))

for i in range(len(df)):
    for j in range(len(df)):
        norm_corr_matrix[i, j] = corr_moments[i, j] / np.sqrt(var_values[i] * var_values[j])

plt.figure(figsize=(10, 8))
sns.heatmap(norm_corr_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Нормована кореляційна матриця')
plt.show()

corr_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Нормована кореляційна матриця')
plt.show()
df_corr == df.corr()
